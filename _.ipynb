# %%
from google.colab import drive
import pandas as pd
from sklearn.datasets import load_boston

drive.mount('/content/drive')


data=pd.read_csv('/content/drive/My Drive/wisc_bc_data.csv', header=0)
global data_frame,df
data_frame = pd.DataFrame(data)
df = pd.DataFrame(data)
display(data_frame)
# Out:
# Mounted at /content/drive
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df = df.drop(labels = "id", axis = 1)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
X = df.drop(labels="diagnosis", axis = 1)
y = df["diagnosis"]

# %%
count_nan_in_df = df.isnull().sum()
print (count_nan_in_df)
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

df_scaled = pd.DataFrame(ss.fit_transform(X),columns=X.columns)#df_res
print(df_scaled)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
count_nan_in_df = df.isnull().sum()
print (count_nan_in_df)
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np 
from pandas import DataFrame
import seaborn as sns

corrMatrix =df.corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5bbc8_row0_col0, #T_5bbc8_row0_col2, #T_5bbc8_row1_col1, #T_5bbc8_row2_col0, #T_5bbc8_row2_col2, #T_5bbc8_row3_col3, #T_5bbc8_row4_col4, #T_5bbc8_row5_col5, #T_5bbc8_row6_col6, #T_5bbc8_row7_col7, #T_5bbc8_row8_col8, #T_5bbc8_row9_col9, #T_5bbc8_row10_col10, #T_5bbc8_row11_col11, #T_5bbc8_row12_col12, #T_5bbc8_row13_col13, #T_5bbc8_row14_col14, #T_5bbc8_row15_col15, #T_5bbc8_row16_col16, #T_5bbc8_row17_col17, #T_5bbc8_row18_col18, #T_5bbc8_row19_col19, #T_5bbc8_row20_col20, #T_5bbc8_row21_col21, #T_5bbc8_row22_col22, #T_5bbc8_row23_col23, #T_5bbc8_row24_col24, #T_5bbc8_row25_col25, #T_5bbc8_row26_col26, #T_5bbc8_row27_col27, #T_5bbc8_row28_col28, #T_5bbc8_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5bbc8_row0_col1, #T_5bbc8_row4_col2, #T_5bbc8_row4_col20, #T_5bbc8_row4_col22, #T_5bbc8_row24_col22, #T_5bbc8_row27_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# ...

# %%
import plotly.express as px
fig = px.imshow(df.corr())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(X.shape)

print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df_scaled,y,test_size=0.1,random_state=0)
print(X_test.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# (57, 30)
# (57,)
# (512, 30)
# (512,)

# %%
from sklearn.decomposition import PCA
pca = PCA()
Xt = pca.fit_transform(X)
plot = plt.scatter(Xt[:,0], Xt[:,1], c=y)
plt.legend(handles=plot.legend_elements()[0], labels=list(df['diagnosis']))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
#
# Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:988: UserWarning:
#
# Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#
# No handles with labels found to put in legend.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X)
X_train_std = sc.transform(X)
#X_test_std = sc.transform(X_test)
#
# Import eigh method for calculating eigenvalues and eigenvectirs
#
from numpy.linalg import eigh
#
# Determine covariance matrix
#
cov_matrix = np.cov(X_train_std, rowvar=False)
#
# Determine eigenvalues and eigenvectors
#
egnvalues, egnvectors = eigh(cov_matrix)
#
# Determine explained variance
#
total_egnvalues = sum(egnvalues)
var_exp = [(i/total_egnvalues) for i in sorted(egnvalues, reverse=True)]
#
# Plot the explained variance against cumulative explained variance
#
import matplotlib.pyplot as plt
cum_sum_exp = np.cumsum(var_exp)
plt.bar(range(0,len(var_exp)), var_exp, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(0,len(cum_sum_exp)), cum_sum_exp, where='mid',label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.decomposition import PCA # Principal Component Analysis module
from sklearn.manifold import TSNE # TSNE module


pca = PCA(n_components=2)
pca_2d = pca.fit_transform(X)

# Invoke the TSNE method
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=2000)
tsne_results = tsne.fit_transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 569 samples in 0.000s...
# [t-SNE] Computed neighbors for 569 samples in 0.088s...
# [t-SNE] Computed conditional probabilities for sample 569 / 569
# [t-SNE] Mean sigma: 38.912067
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.635849
# [t-SNE] KL divergence after 2000 iterations: 0.207326

# %%
plt.figure(figsize = (16,11))
plt.subplot(121)
plt.scatter(pca_2d[:,0],pca_2d[:,1], c = y, 
            cmap = "coolwarm", edgecolor = "None", alpha=0.35)
plt.colorbar()
plt.title('PCA Scatter Plot')
plt.subplot(122)
plt.scatter(tsne_results[:,0],tsne_results[:,1],  c =y, 
            cmap = "coolwarm", edgecolor = "None", alpha=0.35)
plt.colorbar()
plt.title('TSNE Scatter Plot')
plt.show()

# %%
# Calling Sklearn scaling method
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# Invoke the PCA method on the standardised data
pca = PCA(n_components=2)
pca_2d_std = pca.fit_transform(X_std)

# Invoke the TSNE method
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=2000)
tsne_results_std = tsne.fit_transform(X_std)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 569 samples in 0.000s...
# [t-SNE] Computed neighbors for 569 samples in 0.032s...
# [t-SNE] Computed conditional probabilities for sample 569 / 569
# [t-SNE] Mean sigma: 1.522404
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.083130
# [t-SNE] KL divergence after 2000 iterations: 0.874211

# %%
# Plot the TSNE and PCA visuals side-by-side
plt.figure(figsize = (16,11))
plt.subplot(121)
plt.scatter(pca_2d_std[:,0],pca_2d_std[:,1], c = y, 
            cmap = "RdYlGn", edgecolor = "None", alpha=0.35)
plt.colorbar()
plt.title('PCA Scatter Plot')
plt.subplot(122)
plt.scatter(tsne_results_std[:,0],tsne_results_std[:,1],  c = y, 
            cmap = "RdYlGn", edgecolor = "None", alpha=0.35)
plt.colorbar()
plt.title('TSNE Scatter Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2)

kmeans.fit(X)


print(kmeans.cluster_centers_)
y_kmeans = kmeans.predict(X)



centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# [[1.25562991e+01 1.85703653e+01 8.11234703e+01 4.96061872e+02
#   9.48844977e-02 9.10998174e-02 6.24377642e-02 3.34325434e-02
#   1.78057991e-01 6.34540183e-02 3.04190868e-01 1.21515320e+00
#   2.15288059e+00 2.37852922e+01 7.17326256e-03 2.34746895e-02
#   2.87455128e-02 1.06363242e-02 2.06135799e-02 3.74750297e-03
#   1.40439018e+01 2.47095434e+01 9.19375114e+01 6.19647945e+02
#   1.29959110e-01 2.23311758e-01 2.19214947e-01 9.13298425e-02
#   2.83553653e-01 8.32819406e-02]
#  [1.93799237e+01 2.16945802e+01 1.28231298e+02 1.18592977e+03
#   1.01294580e-01 1.48612977e-01 1.76939466e-01 1.00698779e-01
#   1.91539695e-01 6.06029008e-02 7.42803817e-01 1.22253817e+00
#   5.25058015e+00 9.56781679e+01 6.59868702e-03 3.21766947e-02
#   4.24197710e-02 1.56739847e-02 2.03039695e-02 3.95338931e-03
#   2.37094656e+01 2.89126718e+01 1.58496183e+02 1.75302290e+03
#   1.40424733e-01 3.57757710e-01 4.49306107e-01 1.92431069e-01
#   3.11881679e-01 8.61654962e-02]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
# %matplotlib notebook



scaler = StandardScaler()
scaler.fit(X) 
X_scaled = scaler.transform(X)

pca = PCA(n_components=3)
pca.fit(X_scaled) 
X_pca = pca.transform(X_scaled) 

ex_variance=np.var(X_pca,axis=0)
ex_variance_ratio = ex_variance/np.sum(ex_variance)
ex_variance_ratio


Xax = X_pca[:,0]
Yax = X_pca[:,1]
Zax = X_pca[:,2]

cdict = {0:'red',1:'green'}
labl = {0:'D',1:'M'}
marker = {0:'*',1:'o'}
alpha = {0:.3, 1:.5}

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111, projection='3d')

fig.patch.set_facecolor('white')
for l in np.unique(y):
 ix=np.where(y==l)
 ax.scatter(Xax[ix], Yax[ix], Zax[ix], c=cdict[l], s=40,
           label=labl[l], marker=marker[l], alpha=alpha[l])
# for loop ends
ax.set_xlabel("First Principal Component", fontsize=14)
ax.set_ylabel("Second Principal Component", fontsize=14)
ax.set_zlabel("Third Principal Component", fontsize=14)

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-5936cab3c942> in <module>()
#      40 for l in np.unique(y):
#      41  ix=np.where(y==l)
# ---> 42  ax.scatter(Xax[ix], Yax[ix], Zax[ix], c=cdict[l], s=40,
#      43            label=labl[l], marker=marker[l], alpha=alpha[l])
#      44 # for loop ends
#
# KeyError: 'B'

# %%
# imports from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
import pylab
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
# %matplotlib inline
# %pylab inline

from sklearn.manifold import TSNE

#TSNE(3)
data = TSNE(n_components=3, random_state=0).fit_transform(X_scaled)
x, y, z = list(zip(*data))

fig = pylab.figure()
ax = fig.add_subplot(111, projection = '3d')
sc = ax.scatter(x,y,z)

# %% [markdown]
# perplexity : float, optional (default: 30)
# This is a parameter for the number of nearest neighbors based on which t-SNE will determine the potential neighbors. Generally, the larger the dataset the larger should be the perplexity value. Below we will show how different perplexity values can affect the results.

# %%
tsne = TSNE(random_state=0)
tsne_results = tsne.fit_transform(X_scaled)

tsne_results=pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])

plt.scatter(tsne_results['tsne1'], tsne_results['tsne2'], c=y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
#
# Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.

# %%
plt.figure(figsize = (8,4))
plt.subplots_adjust(top = 1.5)

for index, p in enumerate([1, 10, 25, 75]):

    tsne = TSNE(n_components = 2, perplexity = p, random_state=0)
    tsne_results = tsne.fit_transform(X_scaled)
    
    tsne_results=pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])
    
    plt.subplot(2,2,index+1)
    plt.scatter(tsne_results['tsne1'], tsne_results['tsne2'], c=y, s=30)
    plt.title('Perplexity = '+ str(p))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(8, 4))
plt.subplots_adjust(top = 1.5)
tsne = TSNE()
for i in range(4):
    tsne_results = tsne.fit_transform(X_scaled)

    tsne_results=pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])
    
    plt.subplot(2,2,int(i)+1)
    plt.scatter(tsne_results['tsne1'], tsne_results['tsne2'], c=y, s = 30)
    plt.title('Run'+str(int(i)+1))

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# ...

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12)).fit(X_scaled)
visualizer.show()

# %%
# Using scikit-learn to perform K-Means clustering
from sklearn.cluster import KMeans
    
# Specify the number of clusters (3) and fit the data X
kmeans = KMeans(n_clusters=3, random_state=0).fit(X_scaled)
# Plotting the cluster centers and the data points on a 2D plane

plt.scatter(X_scaled[:, 0], X_scaled[:, -1])
    
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x')

plt.title('Data points and cluster centroids')
plt.show()

# %%
pca2 = PCA(n_components=3).fit(X_scaled)
pca2d = pca2.transform(X_scaled)
plt.figure(figsize = (10,10))
sns.scatterplot(pca2d[:,0], pca2d[:,1], 
                hue=y, 
                palette='Set1',
                s=100, alpha=0.2).set_title('KMeans Clusters (3) Derived from Original Dataset', fontsize=12)
plt.legend()
plt.ylabel('PC2')
plt.xlabel('PC1')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
from sklearn.manifold import TSNE
fig, ax = plt.subplots(figsize = (10,8))
df_scaled.columns
data = df_scaled[df_scaled.columns].values
kmeans_clustering = KMeans( n_clusters = 3 )
idx = kmeans_clustering.fit_predict( data )

#use t-sne
X = TSNE(n_components=2, perplexity=10).fit_transform( data )

#fig = plt.figure(1)
#plt.clf()

#plot graph
colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
plt.scatter(X[:,0], X[:,1], c=colors[kmeans_clustering.labels_])
plt.title('K-Means (t-SNE)')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.

# %%
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# create 3d data 
x, label = make_blobs(n_samples=3000, n_features=3, centers=4,
                      random_state=42)

# cluster data
kmeans = KMeans(init="k-means++", n_clusters=3, random_state=42)
kmeans.fit(X_scaled)

# plot clusters and centroids
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_scaled[:,0], X_scaled[:,1], X_scaled[:,2] ,c=kmeans.labels_, cmap='viridis',
           edgecolor='k', s=40, alpha = 0.5)
ax.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
           kmeans.cluster_centers_[:,2], s = 300, c = 'r',
           marker='*', label = 'Centroid')
ax.set_title("3D Kmeans clustering")
ax.set_xlabel("X")
ax.set_ylabel("Y")   
ax.set_zlabel("Z") 
plt.show()

# %%
# Import the python libraries
import numpy as np
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt

 
# Plot the hierarchical clustering as a dendrogram.
temp = hierarchy.linkage(X_scaled, 'single')
plt.figure()
 
dn = hierarchy.dendrogram(
    temp, above_threshold_color="green", color_threshold=.7)




hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
dn1 = hierarchy.dendrogram(Z, ax=axes[0], above_threshold_color='y',
                           orientation='top')
dn2 = hierarchy.dendrogram(Z, ax=axes[1],
                           above_threshold_color='#bcbddc',
                           orientation='right')
hierarchy.set_link_color_palette(None)  # reset to default after use
plt.show()

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt



Z = hierarchy.linkage(X_scaled, 'single')
plt.figure()
dn = hierarchy.dendrogram(Z)



hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
dn1 = hierarchy.dendrogram(Z, ax=axes[0], above_threshold_color='y',
                           orientation='top')
dn2 = hierarchy.dendrogram(Z, ax=axes[1],
                           above_threshold_color='#bcbddc',
                           orientation='right')
hierarchy.set_link_color_palette(None)  # reset to default after use
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(X_scaled, 'complete')

labelList = list(range(len(X_scaled)))
fig = plt.figure(figsize=(30, 28))
fig.patch.set_facecolor('white')
dendrogram(linked,
                orientation='top',
                labels=labelList,
                show_leaf_counts=True)
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(X_scaled, 'ward')

labelList = list(range(len(X_scaled)))
fig = plt.figure(figsize=(30, 28))
fig.patch.set_facecolor('white')
dendrogram(linked,
                orientation='top',
                labels=labelList,
                show_leaf_counts=True)
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(X_scaled, 'single')

labelList = list(range(len(X_scaled)))
fig = plt.figure(figsize=(30, 28))
fig.patch.set_facecolor('white')
dendrogram(linked,
                orientation='top',
                labels=labelList,
                show_leaf_counts=True)
plt.show()

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt



Z = hierarchy.linkage(df_scaled, 'ward')
plt.figure()
dn = hierarchy.dendrogram(Z)



hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
dn1 = hierarchy.dendrogram(Z, ax=axes[0], above_threshold_color='y',
                           orientation='top')
dn2 = hierarchy.dendrogram(Z, ax=axes[1],
                           above_threshold_color='#bcbddc',
                           orientation='right')
hierarchy.set_link_color_palette(None)  # reset to default after use
plt.show()

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt



Z = hierarchy.linkage(df_scaled, 'single')
plt.figure()
dn = hierarchy.dendrogram(Z)



hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
dn1 = hierarchy.dendrogram(Z, ax=axes[0], above_threshold_color='y',
                           orientation='top')
dn2 = hierarchy.dendrogram(Z, ax=axes[1],
                           above_threshold_color='#bcbddc',
                           orientation='right')
hierarchy.set_link_color_palette(None)  # reset to default after use
plt.show()

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt



Z = hierarchy.linkage(df_scaled, 'complete')
plt.figure()
dn = hierarchy.dendrogram(Z)



hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
dn1 = hierarchy.dendrogram(Z, ax=axes[0], above_threshold_color='y',
                           orientation='top')
dn2 = hierarchy.dendrogram(Z, ax=axes[1],
                           above_threshold_color='#bcbddc',
                           orientation='right')
hierarchy.set_link_color_palette(None)  # reset to default after use
plt.show()

# %%
X_scaled.shape
# Out:
# (569, 30)

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt
num_samples_total = 1000
cluster_centers = [(3,3), (7,7)]
num_classes = len(cluster_centers)
epsilon = 1.0
min_samples = 13
# Generate data

# Compute DBSCAN
db = DBSCAN(eps=epsilon, min_samples=min_samples).fit(X_scaled)
labels = db.labels_

no_clusters = len(np.unique(labels) )
no_noise = np.sum(np.array(labels) == -1, axis=0)

print('Estimated no. of clusters: %d' % no_clusters)
print('Estimated no. of noise points: %d' % no_noise)
# Out:
# Estimated no. of clusters: 1
# Estimated no. of noise points: 569

# %%
# Generate scatter plot for training data
colors = list(map(lambda x: '#3b4cc0' if x == 1 else '#b40426', labels))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=colors, marker="o", picker=True)
plt.title(' clusters with data')
plt.xlabel('Axis X[0]')
plt.ylabel('Axis X[1]')
plt.show()

# %%
import sys
import matplotlib.pyplot as plt
from time import time
from sklearn.datasets import load_digits
'''
digits = load_digits()

fig, axes = plt.subplots(2, 5, figsize=(10,5), subplot_kw={'xticks':(), 'yticks':()})
for ax, img in zip(axes.ravel(), digits.images):
    ax.imshow(img)
'''
# print len(digits.data) #1797
colors = ["#476A2A","#7851B8",'#BD3430','#4A2D4E','#875525',
          '#A83683','#4E655E','#853541','#3A3120','#535D8E']

t0=time()
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca = pca.fit(X_scaled)
digits_pca = pca.transform(X_scaled)

plt.figure(figsize=(10,10))
plt.xlim(digits_pca[:,0].min(), digits_pca[:,0].max())
plt.ylim(digits_pca[:,1].min(), digits_pca[:,1].max())

for i in range(len(X_scaled)):
    plt.text(digits_pca[i,0], digits_pca[i,1], str(X_scaled[i]),
             color = colors[X_scaled[i]],
             fontdict={'weight':'bold', 'size':9})
plt.title('PCA')
plt.xlabel("first PC")
plt.ylabel("second PC")
print("PCA time: ", time()-t0)
plt.show()

#feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler = scaler.fit(X_scaled)
scaled_p = scaler.transform(digits_pca)


#PCA -> DBSCAN
t2 = time()
from sklearn.cluster import DBSCAN
import numpy as np

db = DBSCAN(eps=0.122, min_samples=10).fit(X_scaled)
labels = db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print("number of clusters in pca-DBSCAN: ", n_clusters_)

plt.scatter(X_scaled[:,0], X_scaled[:,1], c=labels, s=60, edgecolors='black')
plt.title('PCA -> DBSCAN')
plt.xlabel("first PC")
plt.ylabel("second PC")
print("DBSCAN time: ", time()-t2)
plt.show()



#PCA -> k-MEANS
t3 = time()
from sklearn.cluster import KMeans
km = KMeans(n_clusters=10, random_state=0)
labels_km = km.fit_predict(X_scaled)

plt.scatter(X_scaled[:,0], X_scaled[:,1], c=labels_km, s=60, edgecolors='black')
plt.title('PCA -> k-MEANS')
plt.xlabel("first PC")
plt.ylabel("second PC")
print("k-MEANS time:", time()-t3)
plt.show()


print(labels_km)
print(labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-5be7e2795cf3> in <module>()
#      26 for i in range(len(X_scaled)):
#      27     plt.text(digits_pca[i,0], digits_pca[i,1], str(X_scaled[i]),
# ---> 28              color = colors[X_scaled[i]],
#      29              fontdict={'weight':'bold', 'size':9})
#      30 plt.title('PCA')
#
# TypeError: only integer scalar arrays can be converted to a scalar index
